# %% [markdown]
# ## Objective
# * The objective of this exercise is to explore and visualize the Traffic Index dataset to gain insights and understand the patterns in the data.

# %% [markdown]
# ##Dataset Description

# %% [markdown]
# | Column Name | Description | Data Type |
# | :---------------- | :------: | ----: |
# |   City  |   Name of the city	   | Object |
# | Datetime           |   Date and time of the data entry	   | Object |
# |  TrafficIndexLive    |  Real-time traffic index	   | Int |
# |  Jamscount |  Number of traffic jams	   | Int |
# |   JamsDelay  |   Total delay caused by traffic jams (in minutes)	   | Float |
# |JamsLength           |   Total length of traffic jams (in kilometers)	   | Float |
# |  TrafficIndexWeekAgo    |  Traffic index one week ago	   | Int |
# |  TravelTimeHistoric |  Historical average travel time (in minutes)	   | Float |
# |   TravelTimeLive  |   Real-time travel time (in minutes)	   | Float |

# %%
import pandas as pd
import numpy as np

df2=pd.read_csv("C:\Task (2) Dataset.csv")

df1=pd.read_csv("C:\Task (1) Dataset.csv")

# %%
column_to_merge = df1[['Weather_conditions']]

# %%
df2= pd.concat([df2,c], axis=1)

# %%
df2.head(80)
# Out:
#         City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0   Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1   Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2   Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3   Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4   Abudhabi  2023-07-07 12:01:30                 8         20       62.1
# ..       ...                  ...               ...        ...        ...
# 75  Abudhabi  2023-07-10 11:46:30                12         28       98.4
# 76  Abudhabi  2023-07-10 12:01:30                11         22       76.2
# 77  Abudhabi  2023-07-10 13:01:30                 8          8       22.4
# 78  Abudhabi  2023-07-10 14:01:30                 7          3       11.6
# 79  Abudhabi  2023-07-10 15:46:30                10         27       99.4
#
#     JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive  \
# ...

# %%
print(df2)
# Out:
#            City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0      Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1      Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2      Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3      Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4      Abudhabi  2023-07-07 12:01:30                 8         20       62.1
# ...         ...                  ...               ...        ...        ...
# 66634    Riyadh  2023-12-15 03:01:30                 8         33      127.8
# 66635    Riyadh  2023-12-15 04:31:30                 6         27       87.0
# 66636    Riyadh  2023-12-15 05:01:30                 3         17       49.8
# 66637    Riyadh  2023-12-15 06:01:30                 0         16       61.3
# 66638    Riyadh  2023-12-15 07:01:30                 0         15       39.5
#
# ...

# %% [markdown]
# # Tasks

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df1.describe()
# Out:
#        TrafficIndexLive     JamsCount     JamsDelay    JamsLength  \
# count      66639.000000  66639.000000  66639.000000  66639.000000
# mean          14.043113     74.278531    288.353877     49.316135
# std           13.488906    107.452022    470.013224     85.352525
# min            0.000000      0.000000      0.000000      0.000000
# 25%            3.000000      9.000000     27.700000      3.000000
# 50%           10.000000     29.000000     95.700000     12.200000
# 75%           21.000000     95.000000    336.600000     53.500000
# max          138.000000   1359.000000   9989.400000   1173.900000
#
#        TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# count         66639.000000        62772.000000    62772.000000
# mean             13.981737           70.706601       70.048451
# std              13.454922           10.588384       11.966725
# min               0.000000           49.381346       46.723235
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
import seaborn  as sns
import numpy as np

sns.boxplot(y=df1['TravelTimeLive'])
#outliers alot
#valuebetween 60-80
# Out:
# <AxesSubplot:ylabel='TravelTimeLive'>

# %%
sns.pairplot(df2)

plt.suptitle('Pair Plot')
plt.show()
#here we can see hoe the value incserse with count.

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Traffic_Index, Date).

# %%
df.plot.scatter(x='TrafficIndexLive', y = 'TravelTimeLive')
# Out:
# <AxesSubplot:xlabel='TrafficIndexLive', ylabel='TravelTimeLive'>

# %%
sns.displot(df2, x="TrafficIndexLive")
#trafficindexlive between 0 and 20 that highst

# %% [markdown]
# ### Explore relationships between variables (e.g., Traffic_Index vs. Weather_Condition).

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df2['All_Weather_conditions'] = label_encoder.fit_transform(df2['Weather_conditions'])

# %%
(df2['All_Weather_conditions'].value_counts().head(10)/
len(df2)).plot.bar()
#the haight vale for weather is 9
# Out:
# <AxesSubplot:>

# %%
sns.displot(df2, y ='All_Weather_conditions',x ='TravelTimeLive')
#wither affect traveltime

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.displot(df, x="JamsCount",y="City")
# dubai the JamsCount it's hishgt.
# and medina is slow.

# %%
sns.displot(df1, x="TravelTimeLive",y="City")
# Cairo and Ryadh it's the hihgst timelave

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
#the relationships is between all variables
# if close to 1 that mean the relationship is great under 0.75 no
# if (-) that mean relationship reversed
import seaborn as sn
import matplotlib.pyplot as plt



corr_matrix = df.corr()

sn.heatmap(corr_matrix, annot=True)
plt.show()

# JamsCount and JamsDelay have good relationship

# %% [markdown]
# ## 3. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
#trafficindexlive between 0 and 20 that highst

#the haight vale for weather is 9

# JamsCount and JamsDelay have good relationship

# Cairo and Ryadh it's the hihgst timelave

#here we can see hoe the value incserse with count.

#wither affect traveltime
